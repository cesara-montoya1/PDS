# %% [markdown]
# # Ejemplo 1. Densidad Espectral de Energia.

# %%
# Importar las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 15
n = np.arange(N)
x = np.cos(2*np.pi*n/3) + np.sin(2*np.pi*n/5)

plt.figure()
plt.stem(n, x)
plt.ylabel('Amplitud')
plt.xlabel('Numero de muestras')
plt.grid()
plt.show()

# %%
def fourier_coefs(x_n, Ncoef):
    # x n: senal definida en un periodo
    # Ncoef: numero de componentes a hallar
    N = x_n.size
    cn = np.empty(Ncoef, 'complex_')
    n = np.arange(N)
    for k in np.arange(Ncoef//2+1):
        cn[k] = (1/N) * np.sum(x_n*np.exp(-1j*2*np.pi*k*n/N)) # Calcular la parte positiva de los coef.
        cn[-k] = (1/N) * np.sum(x_n*np.exp(-1j*2*np.pi*-k*n/N)) # Calcular la parte negativa de los coef.
    return cn

# %%
Ck = fourier_coefs(x, N)

for i, ck in enumerate(Ck):
    print(i, ':', ck)
# Out:
# 0 : (-2.0724163126336256e-16+0j)
# 1 : (-1.3322676295501878e-16-2.3684757858670006e-16j)
# 2 : (-1.3322676295501878e-16+2.960594732333751e-17j)
# 3 : (4.4408920985006264e-17-0.5000000000000002j)
# 4 : (-8.141635513917814e-17-2.812564995717063e-16j)
# 5 : (0.5000000000000002+6.957397620984314e-16j)
# 6 : (5.921189464667501e-17-8.881784197001253e-17j)
# 7 : (1.4802973661668753e-16+3.885780586188048e-16j)
# 8 : (1.4802973661668753e-16-3.885780586188048e-16j)
# 9 : (5.921189464667501e-17+8.881784197001253e-17j)
# 10 : (0.5000000000000002-6.957397620984314e-16j)
# 11 : (-8.141635513917814e-17+2.812564995717063e-16j)
# 12 : (4.4408920985006264e-17+0.5000000000000002j)
# 13 : (-1.3322676295501878e-16-2.960594732333751e-17j)
# 14 : (-1.3322676295501878e-16+2.3684757858670006e-16j)

# %%
espectro = np.abs(Ck)**2
k = np.arange(-N//2+1, N//2+1)

plt.figure()
plt.stem(k, espectro[k])
plt.ylabel('$|C_k|^2$')
plt.xlabel('k')
plt.show()
